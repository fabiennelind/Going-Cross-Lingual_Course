# %% [markdown]
# # Test package installation
#
#
# | Authors | Last update |
# |:------ |:----------- |
# | Hauke Licht (https://github.com/haukelicht) | 2023-11-29 |
#
# This notebook simply tests if all required python packages can be installed on Colab.
#
#
#
#
# <a target="_blank" href="https://colab.research.google.com/github/fabiennelind/Going-Cross-Lingual_Course/blob/main/code/test_requirements_installation_colab.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install numpy==1.25.0
# !pip install scipy==1.11.3
# !pip install matplotlib==3.8.2
# !pip install scikit-learn==1.3.2
# !pip install chardet==5.2.0
# !pip install iso639==0.1.4
# !pip install nltk==3.8.1
# !pip install stanza==1.6.1
# !pip install pycld2==0.41
# !pip install lingua-language-detector==2.0.1
# !pip install torch==2.1.0
# !pip install sentencepiece==0.1.99
# !pip install tokenizers==0.14.1
# !pip install datasets==2.14.6
# !pip install accelerate==0.24.1
# !pip install transformers==4.35.0
# !pip install easyNMT==2.0.0
# !pip install sacremoses==0.1.1
# !pip install google-cloud-translate==3.12.1
# !pip install deepl==1.16.1
# !pip install sentence-transformers==2.2.2
# !pip install umap-learn==0.5.4
# !pip install bertopic==0.15.0
# note: I omit the inttallation of ipykernel==6.27.0 and ipywidgets==8.1.1
#        because these requirements are already satisfied on Colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 75.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 22.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %% [markdown]
# ## Comments
#
# Running this on November 29, 2023, I repeatedly got an error meassage reading
#
# ```
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.
#    This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ```
#
# To the best of my knowledge, you can just ignore this message.
#
# Moreover, I got several warning messages reading
#
# ```
# WARNING: The following packages were previously imported in this runtime:
#   ...
# You must restart the runtime in order to use newly installed versions.
# ```
#
# You can ignore this too or simply select "Runtime" > "Restart Runtime" in the menu bar to follow the instruction.
